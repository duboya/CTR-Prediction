# %%
import gc
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. 读取数据

# %%
path = "./data/"
train_file = "train.csv"
test_file = "test.csv"

trainDf = pd.read_csv(path + train_file)

# %%
pos_trainDf = trainDf[trainDf['target'] == 1]
pos_trainDf.shape
# Out:
# (21694, 59)

# %%
neg_trainDf = trainDf[trainDf['target'] == 0]
neg_trainDf.shape
# Out:
# (573518, 59)

# %%
neg_trainDf = trainDf[trainDf['target'] == 0].sample(n=20000, random_state=2018)
trainDf = pd.concat([pos_trainDf, neg_trainDf], axis=0).sample(frac=1.0, random_state=2018)
del pos_trainDf; del neg_trainDf; gc.collect();

# %%
print(trainDf.shape, trainDf['target'].mean())
# Out:
# (41694, 59) 0.5203146735741354

# %%
trainDf, testDf, _, _ = train_test_split(trainDf, trainDf['target'], test_size=0.25, random_state=2018)

print(trainDf['target'].mean(), trainDf.shape)
print(testDf['target'].mean(), testDf.shape)
# Out:
# 0.5215542053086025 (31270, 59)
# 0.5165963161933999 (10424, 59)

# %%
"""
一共59个特征，包括id， target
bin特征17个;cat特征14个;连续特征26个;
"""

columns = trainDf.columns.tolist()
bin_feats = []
cat_feats = []
con_feats = []
for col in  columns:
    if 'bin' in col:
        bin_feats.append(col)
        continue
    if 'cat' in col:
        cat_feats.append(col)
        continue
    if 'id' != col and 'target' != col:
        con_feats.append(col)
        
print(len(bin_feats), bin_feats)
print(len(cat_feats), cat_feats)
print(len(con_feats), con_feats)
# Out:
# 17 ['ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_10_bin', 'ps_ind_11_bin', 'ps_ind_12_bin', 'ps_ind_13_bin', 'ps_ind_16_bin', 'ps_ind_17_bin', 'ps_ind_18_bin', 'ps_calc_15_bin', 'ps_calc_16_bin', 'ps_calc_17_bin', 'ps_calc_18_bin', 'ps_calc_19_bin', 'ps_calc_20_bin']
# 14 ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', 'ps_car_03_cat', 'ps_car_04_cat', 'ps_car_05_cat', 'ps_car_06_cat', 'ps_car_07_cat', 'ps_car_08_cat', 'ps_car_09_cat', 'ps_car_10_cat', 'ps_car_11_cat']
# 26 ['ps_ind_01', 'ps_ind_03', 'ps_ind_14', 'ps_ind_15', 'ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', 'ps_car_13', 'ps_car_14', 'ps_car_15', 'ps_calc_01', 'ps_calc_02', 'ps_calc_03', 'ps_calc_04', 'ps_calc_05', 'ps_calc_06', 'ps_calc_07', 'ps_calc_08', 'ps_calc_09', 'ps_calc_10', 'ps_calc_11', 'ps_calc_12', 'ps_calc_13', 'ps_calc_14']

# %% [markdown]
# ## 2. 特征处理

# %%
trainDf = trainDf.fillna(0)
testDf = testDf.fillna(0)

train_sz = trainDf.shape[0]
combineDf = pd.concat([trainDf, testDf], axis=0)
del trainDf
del testDf
gc.collect()
# Out:
# 31

# %% [markdown]
# ### 2.1 连续特征全部归一化

# %%
from sklearn.preprocessing import MinMaxScaler
for col in con_feats:
    scaler = MinMaxScaler()
    combineDf[col] = scaler.fit_transform(np.array(combineDf[col].values.tolist()).reshape(-1,1))
# Out:
# C:\Users\dby_freedom\Miniconda3\envs\cv\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### 2.2 离散特征one-hot

# %%
for col in bin_feats + cat_feats:
    onehotret = pd.get_dummies(combineDf[col], prefix=col)
    combineDf = pd.concat([combineDf, onehotret], axis=1)

# %%
combineDf.columns.tolist()
# Out:
# ['id',
#  'target',
#  'ps_ind_01',
#  'ps_ind_02_cat',
#  'ps_ind_03',
#  'ps_ind_04_cat',
#  'ps_ind_05_cat',
#  'ps_ind_06_bin',
#  'ps_ind_07_bin',
#  'ps_ind_08_bin',
#  'ps_ind_09_bin',
#  'ps_ind_10_bin',
#  'ps_ind_11_bin',
#  'ps_ind_12_bin',
#  'ps_ind_13_bin',
#  'ps_ind_14',
#  'ps_ind_15',
#  'ps_ind_16_bin',
#  'ps_ind_17_bin',
#  'ps_ind_18_bin',
#  'ps_reg_01',
#  'ps_reg_02',
#  'ps_reg_03',
#  'ps_car_01_cat',
#  'ps_car_02_cat',
#  'ps_car_03_cat',
#  'ps_car_04_cat',
#  'ps_car_05_cat',
#  'ps_car_06_cat',
#  'ps_car_07_cat',
#  'ps_car_08_cat',
#  'ps_car_09_cat',
#  'ps_car_10_cat',
#  'ps_car_11_cat',
#  'ps_car_11',
#  'ps_car_12',
#  'ps_car_13',
#  'ps_car_14',
#  'ps_car_15',
#  'ps_calc_01',
#  'ps_calc_02',
#  'ps_calc_03',
#  'ps_calc_04',
#  'ps_calc_05',
#  'ps_calc_06',
#  'ps_calc_07',
#  'ps_calc_08',
#  'ps_calc_09',
#  'ps_calc_10',
#  'ps_calc_11',
#  'ps_calc_12',
#  'ps_calc_13',
#  'ps_calc_14',
#  'ps_calc_15_bin',
#  'ps_calc_16_bin',
#  'ps_calc_17_bin',
#  'ps_calc_18_bin',
#  'ps_calc_19_bin',
#  'ps_calc_20_bin',
#  'ps_ind_06_bin_0',
#  'ps_ind_06_bin_1',
#  'ps_ind_07_bin_0',
#  'ps_ind_07_bin_1',
#  'ps_ind_08_bin_0',
#  'ps_ind_08_bin_1',
#  'ps_ind_09_bin_0',
#  'ps_ind_09_bin_1',
#  'ps_ind_10_bin_0',
#  'ps_ind_10_bin_1',
#  'ps_ind_11_bin_0',
#  'ps_ind_11_bin_1',
#  'ps_ind_12_bin_0',
#  'ps_ind_12_bin_1',
#  'ps_ind_13_bin_0',
#  'ps_ind_13_bin_1',
#  'ps_ind_16_bin_0',
#  'ps_ind_16_bin_1',
#  'ps_ind_17_bin_0',
#  'ps_ind_17_bin_1',
#  'ps_ind_18_bin_0',
#  'ps_ind_18_bin_1',
#  'ps_calc_15_bin_0',
#  'ps_calc_15_bin_1',
#  'ps_calc_16_bin_0',
#  'ps_calc_16_bin_1',
#  'ps_calc_17_bin_0',
#  'ps_calc_17_bin_1',
#  'ps_calc_18_bin_0',
#  'ps_calc_18_bin_1',
#  'ps_calc_19_bin_0',
#  'ps_calc_19_bin_1',
#  'ps_calc_20_bin_0',
#  'ps_calc_20_bin_1',
#  'ps_ind_02_cat_-1',
#  'ps_ind_02_cat_1',
#  'ps_ind_02_cat_2',
#  'ps_ind_02_cat_3',
#  'ps_ind_02_cat_4',
#  'ps_ind_04_cat_-1',
#  'ps_ind_04_cat_0',
#  'ps_ind_04_cat_1',
#  'ps_ind_05_cat_-1',
#  'ps_ind_05_cat_0',
#  'ps_ind_05_cat_1',
#  'ps_ind_05_cat_2',
#  'ps_ind_05_cat_3',
#  'ps_ind_05_cat_4',
#  'ps_ind_05_cat_5',
#  'ps_ind_05_cat_6',
#  'ps_car_01_cat_-1',
#  'ps_car_01_cat_0',
#  'ps_car_01_cat_1',
#  'ps_car_01_cat_2',
#  'ps_car_01_cat_3',
#  'ps_car_01_cat_4',
#  'ps_car_01_cat_5',
#  'ps_car_01_cat_6',
#  'ps_car_01_cat_7',
#  'ps_car_01_cat_8',
#  'ps_car_01_cat_9',
#  'ps_car_01_cat_10',
#  'ps_car_01_cat_11',
#  'ps_car_02_cat_0',
#  'ps_car_02_cat_1',
#  'ps_car_03_cat_-1',
#  'ps_car_03_cat_0',
#  'ps_car_03_cat_1',
#  'ps_car_04_cat_0',
#  'ps_car_04_cat_1',
#  'ps_car_04_cat_2',
#  'ps_car_04_cat_3',
#  'ps_car_04_cat_4',
#  'ps_car_04_cat_5',
#  'ps_car_04_cat_6',
#  'ps_car_04_cat_7',
#  'ps_car_04_cat_8',
#  'ps_car_04_cat_9',
#  'ps_car_05_cat_-1',
#  'ps_car_05_cat_0',
#  'ps_car_05_cat_1',
#  'ps_car_06_cat_0',
#  'ps_car_06_cat_1',
#  'ps_car_06_cat_2',
#  'ps_car_06_cat_3',
#  'ps_car_06_cat_4',
#  'ps_car_06_cat_5',
#  'ps_car_06_cat_6',
#  'ps_car_06_cat_7',
#  'ps_car_06_cat_8',
#  'ps_car_06_cat_9',
#  'ps_car_06_cat_10',
#  'ps_car_06_cat_11',
#  'ps_car_06_cat_12',
#  'ps_car_06_cat_13',
#  'ps_car_06_cat_14',
#  'ps_car_06_cat_15',
#  'ps_car_06_cat_16',
#  'ps_car_06_cat_17',
#  'ps_car_07_cat_-1',
#  'ps_car_07_cat_0',
#  'ps_car_07_cat_1',
#  'ps_car_08_cat_0',
#  'ps_car_08_cat_1',
#  'ps_car_09_cat_-1',
#  'ps_car_09_cat_0',
#  'ps_car_09_cat_1',
#  'ps_car_09_cat_2',
#  'ps_car_09_cat_3',
#  'ps_car_09_cat_4',
#  'ps_car_10_cat_0',
#  'ps_car_10_cat_1',
#  'ps_car_10_cat_2',
#  'ps_car_11_cat_1',
#  'ps_car_11_cat_2',
#  'ps_car_11_cat_3',
#  'ps_car_11_cat_4',
#  'ps_car_11_cat_5',
#  'ps_car_11_cat_6',
#  'ps_car_11_cat_7',
#  'ps_car_11_cat_8',
#  'ps_car_11_cat_9',
#  'ps_car_11_cat_10',
#  'ps_car_11_cat_11',
#  'ps_car_11_cat_12',
#  'ps_car_11_cat_13',
#  'ps_car_11_cat_14',
#  'ps_car_11_cat_15',
#  'ps_car_11_cat_16',
#  'ps_car_11_cat_17',
#  'ps_car_11_cat_18',
#  'ps_car_11_cat_19',
#  'ps_car_11_cat_20',
#  'ps_car_11_cat_21',
#  'ps_car_11_cat_22',
#  'ps_car_11_cat_23',
#  'ps_car_11_cat_24',
#  'ps_car_11_cat_25',
#  'ps_car_11_cat_26',
#  'ps_car_11_cat_27',
#  'ps_car_11_cat_28',
#  'ps_car_11_cat_29',
#  'ps_car_11_cat_30',
#  'ps_car_11_cat_31',
#  'ps_car_11_cat_32',
#  'ps_car_11_cat_33',
#  'ps_car_11_cat_34',
#  'ps_car_11_cat_35',
#  'ps_car_11_cat_36',
#  'ps_car_11_cat_37',
#  'ps_car_11_cat_38',
#  'ps_car_11_cat_39',
#  'ps_car_11_cat_40',
#  'ps_car_11_cat_41',
#  'ps_car_11_cat_42',
#  'ps_car_11_cat_43',
#  'ps_car_11_cat_44',
#  'ps_car_11_cat_45',
#  'ps_car_11_cat_46',
#  'ps_car_11_cat_47',
#  'ps_car_11_cat_48',
#  'ps_car_11_cat_49',
#  'ps_car_11_cat_50',
#  'ps_car_11_cat_51',
#  'ps_car_11_cat_52',
#  'ps_car_11_cat_53',
#  'ps_car_11_cat_54',
#  'ps_car_11_cat_55',
#  'ps_car_11_cat_56',
#  'ps_car_11_cat_57',
#  'ps_car_11_cat_58',
#  'ps_car_11_cat_59',
#  'ps_car_11_cat_60',
#  'ps_car_11_cat_61',
#  'ps_car_11_cat_62',
#  'ps_car_11_cat_63',
#  'ps_car_11_cat_64',
#  'ps_car_11_cat_65',
#  'ps_car_11_cat_66',
#  'ps_car_11_cat_67',
#  'ps_car_11_cat_68',
#  'ps_car_11_cat_69',
#  'ps_car_11_cat_70',
#  'ps_car_11_cat_71',
#  'ps_car_11_cat_72',
#  'ps_car_11_cat_73',
#  'ps_car_11_cat_74',
#  'ps_car_11_cat_75',
#  'ps_car_11_cat_76',
#  'ps_car_11_cat_77',
#  'ps_car_11_cat_78',
#  'ps_car_11_cat_79',
#  'ps_car_11_cat_80',
#  'ps_car_11_cat_81',
#  'ps_car_11_cat_82',
#  'ps_car_11_cat_83',
#  'ps_car_11_cat_84',
#  'ps_car_11_cat_85',
#  'ps_car_11_cat_86',
#  'ps_car_11_cat_87',
#  'ps_car_11_cat_88',
#  'ps_car_11_cat_89',
#  'ps_car_11_cat_90',
#  'ps_car_11_cat_91',
#  'ps_car_11_cat_92',
#  'ps_car_11_cat_93',
#  'ps_car_11_cat_94',
#  'ps_car_11_cat_95',
#  'ps_car_11_cat_96',
#  'ps_car_11_cat_97',
#  'ps_car_11_cat_98',
#  'ps_car_11_cat_99',
#  'ps_car_11_cat_100',
#  'ps_car_11_cat_101',
#  'ps_car_11_cat_102',
#  'ps_car_11_cat_103',
#  'ps_car_11_cat_104']

# %%
combineDf.shape
# Out:
# (41694, 276)

# %% [markdown]
# ## 3. 训练模型

# %%
label = 'target'
onehot_feats = [col for col in combineDf.columns if col not in ['id', 'target'] + con_feats + cat_feats + bin_feats]

# %%
np.shape(onehot_feats)
# Out:
# (217,)

# %%
train = combineDf[:train_sz]
test = combineDf[train_sz:]
print("Train.shape: {0}, Test.shape: {0}".format(train.shape, test.shape))
del combineDf
gc.collect()
# Out:
# Train.shape: (31270, 276), Test.shape: (31270, 276)
# 21

# %% [markdown]
# ### 3.1 LR模型

# %%
lr_feats = con_feats + onehot_feats
lr = LogisticRegression(penalty='l2', C=1)
lr.fit(train[lr_feats], train[label].values)
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.metrics import roc_auc_score,accuracy_score

def do_model_metric(y_true, y_pred, y_pred_prob):
    print("Predict 1 percent: {0}".format(np.mean(y_pred)))
    print("Label 1 percent: {0}".format(train[label].mean()))
    print("AUC: {0:.3}".format(roc_auc_score(y_true=y_true, y_score=y_pred_prob[:,1])))
    print("Accuracy: {0}".format(accuracy_score(y_true=y_true, y_pred=y_pred)))

# %%
print("Train............")
do_model_metric(y_true=train[label], y_pred=lr.predict(train[lr_feats]), y_pred_prob=lr.predict_proba(train[lr_feats]))
# Out:
# Train............
# Predict 1 percent: 0.5394627438439399
# Label 1 percent: 0.5215542053086025
# AUC: 0.637
# Accuracy: 0.594755356571794

# %%
print("\n\n")
print("Test.............")
do_model_metric(y_true=test[label], y_pred=lr.predict(test[lr_feats]), y_pred_prob=lr.predict_proba(test[lr_feats]))
# Out:
# Test.............
# Predict 1 percent: 0.5304105909439755
# Label 1 percent: 0.5215542053086025
# AUC: 0.629
# Accuracy: 0.5909439754412893

# %% [markdown]
# ## 3.2 GBDT

# %%
lgb_feats = con_feats + cat_feats + bin_feats
categorical_feature_list = cat_feats + bin_feats

# %%
np.shape(lgb_feats)
# Out:
# (57,)

# %%
np.shape(categorical_feature_list)
# Out:
# (31,)

# %%
import lightgbm as lgb


lgb_params ={
    'objective':'binary',
    'boosting_type': 'gbdt',
    'metric':'auc',
    'learning_rate': 0.01,
    'num_leaves': 5,
    'max_depth': 4,
    'min_data_in_leaf': 100,
    'bagging_fraction': 0.8,
    'feature_fraction':0.8,
    'bagging_freq':10,
    'lambda_l1':0.2,
    'lambda_l2':0.2,
    'scale_pos_weight':1,
}

# %%
lgbtrain = lgb.Dataset(train[lgb_feats].values, label=train[label].values,
                          feature_name=lgb_feats,
                          categorical_feature=categorical_feature_list
                          )
lgbvalid = lgb.Dataset(test[lgb_feats].values, label=test[label].values,
                          feature_name=lgb_feats,
                          categorical_feature=categorical_feature_list
                          )

# %%
evals_results = {}
print('train.............')
lgb_model = lgb.train(lgb_params,
                 lgbtrain,
                 valid_sets=lgbvalid,
                 evals_result=evals_results,
                 num_boost_round=1000,
                 early_stopping_rounds=60,
                 verbose_eval=50,
                 categorical_feature=categorical_feature_list,
                 )
# Out:
# train.............
# Training until validation scores don't improve for 60 rounds.
# C:\Users\dby_freedom\Miniconda3\envs\cv\lib\site-packages\lightgbm\basic.py:685: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [50]	valid_0's auc: 0.607672
# [100]	valid_0's auc: 0.614587
# [150]	valid_0's auc: 0.619941
# [200]	valid_0's auc: 0.621069
# [250]	valid_0's auc: 0.622795
# [300]	valid_0's auc: 0.62422
# [350]	valid_0's auc: 0.625249
# [400]	valid_0's auc: 0.625787
# [450]	valid_0's auc: 0.626351
# [500]	valid_0's auc: 0.626982
# [550]	valid_0's auc: 0.627196
# [600]	valid_0's auc: 0.62759
# [650]	valid_0's auc: 0.627911
# [700]	valid_0's auc: 0.627982
# [750]	valid_0's auc: 0.628257
# [800]	valid_0's auc: 0.628453
# [850]	valid_0's auc: 0.628526
# Early stopping, best iteration is:
# [818]	valid_0's auc: 0.628596

# %% [markdown]
# ### 3.3 LR + GBDT

# %%
train_sz = train.shape[0]
combineDf = pd.concat([train, test], axis=0, ignore_index=True)

# %%
#得到叶节点编号 Feature Transformation
gbdt_feats_vals = lgb_model.predict(combineDf[lgb_feats], pred_leaf=True)
gbdt_feats_vals
# Out:
# array([[3, 4, 4, ..., 2, 2, 2],
#        [4, 0, 0, ..., 2, 2, 2],
#        [4, 0, 0, ..., 0, 0, 0],
#        ...,
#        [3, 4, 4, ..., 4, 4, 2],
#        [0, 0, 0, ..., 3, 3, 2],
#        [2, 3, 3, ..., 2, 2, 3]])

# %%
# 因为是818轮结束的LightGBM训练，所以LightGBM一共有818棵树，对应每行样本有818个索引值（一个索引对应一棵树的叶子节点索引）

np.shape(gbdt_feats_vals)
# Out:
# (41694, 818)

# %%
gbdt_feats_vals[:10,:10]
# Out:
# array([[3, 4, 4, 2, 1, 3, 4, 1, 1, 2],
#        [4, 0, 0, 0, 0, 0, 0, 0, 0, 4],
#        [4, 0, 0, 0, 0, 0, 0, 0, 0, 0],
#        [4, 0, 0, 0, 0, 0, 0, 0, 0, 1],
#        [2, 3, 3, 4, 3, 4, 3, 4, 4, 3],
#        [4, 0, 0, 0, 0, 0, 0, 3, 3, 3],
#        [1, 1, 1, 3, 4, 1, 4, 1, 1, 4],
#        [3, 4, 4, 3, 1, 3, 4, 1, 1, 3],
#        [1, 1, 1, 4, 4, 1, 4, 1, 1, 3],
#        [2, 3, 3, 4, 3, 0, 3, 3, 3, 4]])

# %%
gbdt_columns = ["gbdt_leaf_indices_" + str(i) for i in range(0, gbdt_feats_vals.shape[1])]

# %%
gbdt_columns
# Out:
# ['gbdt_leaf_indices_0',
#  'gbdt_leaf_indices_1',
#  'gbdt_leaf_indices_2',
#  'gbdt_leaf_indices_3',
#  'gbdt_leaf_indices_4',
#  'gbdt_leaf_indices_5',
#  'gbdt_leaf_indices_6',
#  'gbdt_leaf_indices_7',
#  'gbdt_leaf_indices_8',
#  'gbdt_leaf_indices_9',
#  'gbdt_leaf_indices_10',
#  'gbdt_leaf_indices_11',
#  'gbdt_leaf_indices_12',
#  'gbdt_leaf_indices_13',
#  'gbdt_leaf_indices_14',
#  'gbdt_leaf_indices_15',
#  'gbdt_leaf_indices_16',
#  'gbdt_leaf_indices_17',
#  'gbdt_leaf_indices_18',
#  'gbdt_leaf_indices_19',
#  'gbdt_leaf_indices_20',
#  'gbdt_leaf_indices_21',
#  'gbdt_leaf_indices_22',
#  'gbdt_leaf_indices_23',
#  'gbdt_leaf_indices_24',
#  'gbdt_leaf_indices_25',
#  'gbdt_leaf_indices_26',
#  'gbdt_leaf_indices_27',
#  'gbdt_leaf_indices_28',
#  'gbdt_leaf_indices_29',
#  'gbdt_leaf_indices_30',
#  'gbdt_leaf_indices_31',
#  'gbdt_leaf_indices_32',
#  'gbdt_leaf_indices_33',
#  'gbdt_leaf_indices_34',
#  'gbdt_leaf_indices_35',
#  'gbdt_leaf_indices_36',
#  'gbdt_leaf_indices_37',
#  'gbdt_leaf_indices_38',
#  'gbdt_leaf_indices_39',
#  'gbdt_leaf_indices_40',
#  'gbdt_leaf_indices_41',
#  'gbdt_leaf_indices_42',
#  'gbdt_leaf_indices_43',
#  'gbdt_leaf_indices_44',
#  'gbdt_leaf_indices_45',
#  'gbdt_leaf_indices_46',
#  'gbdt_leaf_indices_47',
#  'gbdt_leaf_indices_48',
#  'gbdt_leaf_indices_49',
#  'gbdt_leaf_indices_50',
#  'gbdt_leaf_indices_51',
#  'gbdt_leaf_indices_52',
#  'gbdt_leaf_indices_53',
#  'gbdt_leaf_indices_54',
#  'gbdt_leaf_indices_55',
#  'gbdt_leaf_indices_56',
#  'gbdt_leaf_indices_57',
#  'gbdt_leaf_indices_58',
#  'gbdt_leaf_indices_59',
#  'gbdt_leaf_indices_60',
#  'gbdt_leaf_indices_61',
#  'gbdt_leaf_indices_62',
#  'gbdt_leaf_indices_63',
#  'gbdt_leaf_indices_64',
#  'gbdt_leaf_indices_65',
#  'gbdt_leaf_indices_66',
#  'gbdt_leaf_indices_67',
#  'gbdt_leaf_indices_68',
#  'gbdt_leaf_indices_69',
#  'gbdt_leaf_indices_70',
#  'gbdt_leaf_indices_71',
#  'gbdt_leaf_indices_72',
#  'gbdt_leaf_indices_73',
#  'gbdt_leaf_indices_74',
#  'gbdt_leaf_indices_75',
#  'gbdt_leaf_indices_76',
#  'gbdt_leaf_indices_77',
#  'gbdt_leaf_indices_78',
#  'gbdt_leaf_indices_79',
#  'gbdt_leaf_indices_80',
#  'gbdt_leaf_indices_81',
#  'gbdt_leaf_indices_82',
#  'gbdt_leaf_indices_83',
#  'gbdt_leaf_indices_84',
#  'gbdt_leaf_indices_85',
#  'gbdt_leaf_indices_86',
#  'gbdt_leaf_indices_87',
#  'gbdt_leaf_indices_88',
#  'gbdt_leaf_indices_89',
#  'gbdt_leaf_indices_90',
#  'gbdt_leaf_indices_91',
#  'gbdt_leaf_indices_92',
#  'gbdt_leaf_indices_93',
#  'gbdt_leaf_indices_94',
#  'gbdt_leaf_indices_95',
#  'gbdt_leaf_indices_96',
#  'gbdt_leaf_indices_97',
#  'gbdt_leaf_indices_98',
#  'gbdt_leaf_indices_99',
#  'gbdt_leaf_indices_100',
#  'gbdt_leaf_indices_101',
#  'gbdt_leaf_indices_102',
#  'gbdt_leaf_indices_103',
#  'gbdt_leaf_indices_104',
#  'gbdt_leaf_indices_105',
#  'gbdt_leaf_indices_106',
#  'gbdt_leaf_indices_107',
#  'gbdt_leaf_indices_108',
#  'gbdt_leaf_indices_109',
#  'gbdt_leaf_indices_110',
#  'gbdt_leaf_indices_111',
#  'gbdt_leaf_indices_112',
#  'gbdt_leaf_indices_113',
#  'gbdt_leaf_indices_114',
#  'gbdt_leaf_indices_115',
#  'gbdt_leaf_indices_116',
#  'gbdt_leaf_indices_117',
#  'gbdt_leaf_indices_118',
#  'gbdt_leaf_indices_119',
#  'gbdt_leaf_indices_120',
#  'gbdt_leaf_indices_121',
#  'gbdt_leaf_indices_122',
#  'gbdt_leaf_indices_123',
#  'gbdt_leaf_indices_124',
#  'gbdt_leaf_indices_125',
#  'gbdt_leaf_indices_126',
#  'gbdt_leaf_indices_127',
#  'gbdt_leaf_indices_128',
#  'gbdt_leaf_indices_129',
#  'gbdt_leaf_indices_130',
#  'gbdt_leaf_indices_131',
#  'gbdt_leaf_indices_132',
#  'gbdt_leaf_indices_133',
#  'gbdt_leaf_indices_134',
#  'gbdt_leaf_indices_135',
#  'gbdt_leaf_indices_136',
#  'gbdt_leaf_indices_137',
#  'gbdt_leaf_indices_138',
#  'gbdt_leaf_indices_139',
#  'gbdt_leaf_indices_140',
#  'gbdt_leaf_indices_141',
#  'gbdt_leaf_indices_142',
#  'gbdt_leaf_indices_143',
#  'gbdt_leaf_indices_144',
#  'gbdt_leaf_indices_145',
#  'gbdt_leaf_indices_146',
#  'gbdt_leaf_indices_147',
#  'gbdt_leaf_indices_148',
#  'gbdt_leaf_indices_149',
#  'gbdt_leaf_indices_150',
#  'gbdt_leaf_indices_151',
#  'gbdt_leaf_indices_152',
#  'gbdt_leaf_indices_153',
#  'gbdt_leaf_indices_154',
#  'gbdt_leaf_indices_155',
#  'gbdt_leaf_indices_156',
#  'gbdt_leaf_indices_157',
#  'gbdt_leaf_indices_158',
#  'gbdt_leaf_indices_159',
#  'gbdt_leaf_indices_160',
#  'gbdt_leaf_indices_161',
#  'gbdt_leaf_indices_162',
#  'gbdt_leaf_indices_163',
#  'gbdt_leaf_indices_164',
#  'gbdt_leaf_indices_165',
#  'gbdt_leaf_indices_166',
#  'gbdt_leaf_indices_167',
#  'gbdt_leaf_indices_168',
#  'gbdt_leaf_indices_169',
#  'gbdt_leaf_indices_170',
#  'gbdt_leaf_indices_171',
#  'gbdt_leaf_indices_172',
#  'gbdt_leaf_indices_173',
#  'gbdt_leaf_indices_174',
#  'gbdt_leaf_indices_175',
#  'gbdt_leaf_indices_176',
#  'gbdt_leaf_indices_177',
#  'gbdt_leaf_indices_178',
#  'gbdt_leaf_indices_179',
#  'gbdt_leaf_indices_180',
#  'gbdt_leaf_indices_181',
#  'gbdt_leaf_indices_182',
#  'gbdt_leaf_indices_183',
#  'gbdt_leaf_indices_184',
#  'gbdt_leaf_indices_185',
#  'gbdt_leaf_indices_186',
#  'gbdt_leaf_indices_187',
#  'gbdt_leaf_indices_188',
#  'gbdt_leaf_indices_189',
#  'gbdt_leaf_indices_190',
#  'gbdt_leaf_indices_191',
#  'gbdt_leaf_indices_192',
#  'gbdt_leaf_indices_193',
#  'gbdt_leaf_indices_194',
#  'gbdt_leaf_indices_195',
#  'gbdt_leaf_indices_196',
#  'gbdt_leaf_indices_197',
#  'gbdt_leaf_indices_198',
#  'gbdt_leaf_indices_199',
#  'gbdt_leaf_indices_200',
#  'gbdt_leaf_indices_201',
#  'gbdt_leaf_indices_202',
#  'gbdt_leaf_indices_203',
#  'gbdt_leaf_indices_204',
#  'gbdt_leaf_indices_205',
#  'gbdt_leaf_indices_206',
#  'gbdt_leaf_indices_207',
#  'gbdt_leaf_indices_208',
#  'gbdt_leaf_indices_209',
#  'gbdt_leaf_indices_210',
#  'gbdt_leaf_indices_211',
#  'gbdt_leaf_indices_212',
#  'gbdt_leaf_indices_213',
#  'gbdt_leaf_indices_214',
#  'gbdt_leaf_indices_215',
#  'gbdt_leaf_indices_216',
#  'gbdt_leaf_indices_217',
#  'gbdt_leaf_indices_218',
#  'gbdt_leaf_indices_219',
#  'gbdt_leaf_indices_220',
#  'gbdt_leaf_indices_221',
#  'gbdt_leaf_indices_222',
#  'gbdt_leaf_indices_223',
#  'gbdt_leaf_indices_224',
#  'gbdt_leaf_indices_225',
#  'gbdt_leaf_indices_226',
#  'gbdt_leaf_indices_227',
#  'gbdt_leaf_indices_228',
#  'gbdt_leaf_indices_229',
#  'gbdt_leaf_indices_230',
#  'gbdt_leaf_indices_231',
#  'gbdt_leaf_indices_232',
#  'gbdt_leaf_indices_233',
#  'gbdt_leaf_indices_234',
#  'gbdt_leaf_indices_235',
#  'gbdt_leaf_indices_236',
#  'gbdt_leaf_indices_237',
#  'gbdt_leaf_indices_238',
#  'gbdt_leaf_indices_239',
#  'gbdt_leaf_indices_240',
#  'gbdt_leaf_indices_241',
#  'gbdt_leaf_indices_242',
#  'gbdt_leaf_indices_243',
#  'gbdt_leaf_indices_244',
#  'gbdt_leaf_indices_245',
#  'gbdt_leaf_indices_246',
#  'gbdt_leaf_indices_247',
#  'gbdt_leaf_indices_248',
#  'gbdt_leaf_indices_249',
#  'gbdt_leaf_indices_250',
#  'gbdt_leaf_indices_251',
#  'gbdt_leaf_indices_252',
#  'gbdt_leaf_indices_253',
#  'gbdt_leaf_indices_254',
#  'gbdt_leaf_indices_255',
#  'gbdt_leaf_indices_256',
#  'gbdt_leaf_indices_257',
#  'gbdt_leaf_indices_258',
#  'gbdt_leaf_indices_259',
#  'gbdt_leaf_indices_260',
#  'gbdt_leaf_indices_261',
#  'gbdt_leaf_indices_262',
#  'gbdt_leaf_indices_263',
#  'gbdt_leaf_indices_264',
#  'gbdt_leaf_indices_265',
#  'gbdt_leaf_indices_266',
#  'gbdt_leaf_indices_267',
#  'gbdt_leaf_indices_268',
#  'gbdt_leaf_indices_269',
#  'gbdt_leaf_indices_270',
#  'gbdt_leaf_indices_271',
#  'gbdt_leaf_indices_272',
#  'gbdt_leaf_indices_273',
#  'gbdt_leaf_indices_274',
#  'gbdt_leaf_indices_275',
#  'gbdt_leaf_indices_276',
#  'gbdt_leaf_indices_277',
#  'gbdt_leaf_indices_278',
#  'gbdt_leaf_indices_279',
#  'gbdt_leaf_indices_280',
#  'gbdt_leaf_indices_281',
#  'gbdt_leaf_indices_282',
#  'gbdt_leaf_indices_283',
#  'gbdt_leaf_indices_284',
#  'gbdt_leaf_indices_285',
#  'gbdt_leaf_indices_286',
#  'gbdt_leaf_indices_287',
#  'gbdt_leaf_indices_288',
#  'gbdt_leaf_indices_289',
#  'gbdt_leaf_indices_290',
#  'gbdt_leaf_indices_291',
#  'gbdt_leaf_indices_292',
#  'gbdt_leaf_indices_293',
#  'gbdt_leaf_indices_294',
#  'gbdt_leaf_indices_295',
#  'gbdt_leaf_indices_296',
#  'gbdt_leaf_indices_297',
#  'gbdt_leaf_indices_298',
#  'gbdt_leaf_indices_299',
#  'gbdt_leaf_indices_300',
#  'gbdt_leaf_indices_301',
#  'gbdt_leaf_indices_302',
#  'gbdt_leaf_indices_303',
#  'gbdt_leaf_indices_304',
#  'gbdt_leaf_indices_305',
#  'gbdt_leaf_indices_306',
#  'gbdt_leaf_indices_307',
#  'gbdt_leaf_indices_308',
#  'gbdt_leaf_indices_309',
#  'gbdt_leaf_indices_310',
#  'gbdt_leaf_indices_311',
#  'gbdt_leaf_indices_312',
#  'gbdt_leaf_indices_313',
#  'gbdt_leaf_indices_314',
#  'gbdt_leaf_indices_315',
#  'gbdt_leaf_indices_316',
#  'gbdt_leaf_indices_317',
#  'gbdt_leaf_indices_318',
#  'gbdt_leaf_indices_319',
#  'gbdt_leaf_indices_320',
#  'gbdt_leaf_indices_321',
#  'gbdt_leaf_indices_322',
#  'gbdt_leaf_indices_323',
#  'gbdt_leaf_indices_324',
#  'gbdt_leaf_indices_325',
#  'gbdt_leaf_indices_326',
#  'gbdt_leaf_indices_327',
#  'gbdt_leaf_indices_328',
#  'gbdt_leaf_indices_329',
#  'gbdt_leaf_indices_330',
#  'gbdt_leaf_indices_331',
#  'gbdt_leaf_indices_332',
#  'gbdt_leaf_indices_333',
#  'gbdt_leaf_indices_334',
#  'gbdt_leaf_indices_335',
#  'gbdt_leaf_indices_336',
#  'gbdt_leaf_indices_337',
#  'gbdt_leaf_indices_338',
#  'gbdt_leaf_indices_339',
#  'gbdt_leaf_indices_340',
#  'gbdt_leaf_indices_341',
#  'gbdt_leaf_indices_342',
#  'gbdt_leaf_indices_343',
#  'gbdt_leaf_indices_344',
#  'gbdt_leaf_indices_345',
#  'gbdt_leaf_indices_346',
#  'gbdt_leaf_indices_347',
#  'gbdt_leaf_indices_348',
#  'gbdt_leaf_indices_349',
#  'gbdt_leaf_indices_350',
#  'gbdt_leaf_indices_351',
#  'gbdt_leaf_indices_352',
#  'gbdt_leaf_indices_353',
#  'gbdt_leaf_indices_354',
#  'gbdt_leaf_indices_355',
#  'gbdt_leaf_indices_356',
#  'gbdt_leaf_indices_357',
#  'gbdt_leaf_indices_358',
#  'gbdt_leaf_indices_359',
#  'gbdt_leaf_indices_360',
#  'gbdt_leaf_indices_361',
#  'gbdt_leaf_indices_362',
#  'gbdt_leaf_indices_363',
#  'gbdt_leaf_indices_364',
#  'gbdt_leaf_indices_365',
#  'gbdt_leaf_indices_366',
#  'gbdt_leaf_indices_367',
#  'gbdt_leaf_indices_368',
#  'gbdt_leaf_indices_369',
#  'gbdt_leaf_indices_370',
#  'gbdt_leaf_indices_371',
#  'gbdt_leaf_indices_372',
#  'gbdt_leaf_indices_373',
#  'gbdt_leaf_indices_374',
#  'gbdt_leaf_indices_375',
#  'gbdt_leaf_indices_376',
#  'gbdt_leaf_indices_377',
#  'gbdt_leaf_indices_378',
#  'gbdt_leaf_indices_379',
#  'gbdt_leaf_indices_380',
#  'gbdt_leaf_indices_381',
#  'gbdt_leaf_indices_382',
#  'gbdt_leaf_indices_383',
#  'gbdt_leaf_indices_384',
#  'gbdt_leaf_indices_385',
#  'gbdt_leaf_indices_386',
#  'gbdt_leaf_indices_387',
#  'gbdt_leaf_indices_388',
#  'gbdt_leaf_indices_389',
#  'gbdt_leaf_indices_390',
#  'gbdt_leaf_indices_391',
#  'gbdt_leaf_indices_392',
#  'gbdt_leaf_indices_393',
#  'gbdt_leaf_indices_394',
#  'gbdt_leaf_indices_395',
#  'gbdt_leaf_indices_396',
#  'gbdt_leaf_indices_397',
#  'gbdt_leaf_indices_398',
#  'gbdt_leaf_indices_399',
#  'gbdt_leaf_indices_400',
#  'gbdt_leaf_indices_401',
#  'gbdt_leaf_indices_402',
#  'gbdt_leaf_indices_403',
#  'gbdt_leaf_indices_404',
#  'gbdt_leaf_indices_405',
#  'gbdt_leaf_indices_406',
#  'gbdt_leaf_indices_407',
#  'gbdt_leaf_indices_408',
#  'gbdt_leaf_indices_409',
#  'gbdt_leaf_indices_410',
#  'gbdt_leaf_indices_411',
#  'gbdt_leaf_indices_412',
#  'gbdt_leaf_indices_413',
#  'gbdt_leaf_indices_414',
#  'gbdt_leaf_indices_415',
#  'gbdt_leaf_indices_416',
#  'gbdt_leaf_indices_417',
#  'gbdt_leaf_indices_418',
#  'gbdt_leaf_indices_419',
#  'gbdt_leaf_indices_420',
#  'gbdt_leaf_indices_421',
#  'gbdt_leaf_indices_422',
#  'gbdt_leaf_indices_423',
#  'gbdt_leaf_indices_424',
#  'gbdt_leaf_indices_425',
#  'gbdt_leaf_indices_426',
#  'gbdt_leaf_indices_427',
#  'gbdt_leaf_indices_428',
#  'gbdt_leaf_indices_429',
#  'gbdt_leaf_indices_430',
#  'gbdt_leaf_indices_431',
#  'gbdt_leaf_indices_432',
#  'gbdt_leaf_indices_433',
#  'gbdt_leaf_indices_434',
#  'gbdt_leaf_indices_435',
#  'gbdt_leaf_indices_436',
#  'gbdt_leaf_indices_437',
#  'gbdt_leaf_indices_438',
#  'gbdt_leaf_indices_439',
#  'gbdt_leaf_indices_440',
#  'gbdt_leaf_indices_441',
#  'gbdt_leaf_indices_442',
#  'gbdt_leaf_indices_443',
#  'gbdt_leaf_indices_444',
#  'gbdt_leaf_indices_445',
#  'gbdt_leaf_indices_446',
#  'gbdt_leaf_indices_447',
#  'gbdt_leaf_indices_448',
#  'gbdt_leaf_indices_449',
#  'gbdt_leaf_indices_450',
#  'gbdt_leaf_indices_451',
#  'gbdt_leaf_indices_452',
#  'gbdt_leaf_indices_453',
#  'gbdt_leaf_indices_454',
#  'gbdt_leaf_indices_455',
#  'gbdt_leaf_indices_456',
#  'gbdt_leaf_indices_457',
#  'gbdt_leaf_indices_458',
#  'gbdt_leaf_indices_459',
#  'gbdt_leaf_indices_460',
#  'gbdt_leaf_indices_461',
#  'gbdt_leaf_indices_462',
#  'gbdt_leaf_indices_463',
#  'gbdt_leaf_indices_464',
#  'gbdt_leaf_indices_465',
#  'gbdt_leaf_indices_466',
#  'gbdt_leaf_indices_467',
#  'gbdt_leaf_indices_468',
#  'gbdt_leaf_indices_469',
#  'gbdt_leaf_indices_470',
#  'gbdt_leaf_indices_471',
#  'gbdt_leaf_indices_472',
#  'gbdt_leaf_indices_473',
#  'gbdt_leaf_indices_474',
#  'gbdt_leaf_indices_475',
#  'gbdt_leaf_indices_476',
#  'gbdt_leaf_indices_477',
#  'gbdt_leaf_indices_478',
#  'gbdt_leaf_indices_479',
#  'gbdt_leaf_indices_480',
#  'gbdt_leaf_indices_481',
#  'gbdt_leaf_indices_482',
#  'gbdt_leaf_indices_483',
#  'gbdt_leaf_indices_484',
#  'gbdt_leaf_indices_485',
#  'gbdt_leaf_indices_486',
#  'gbdt_leaf_indices_487',
#  'gbdt_leaf_indices_488',
#  'gbdt_leaf_indices_489',
#  'gbdt_leaf_indices_490',
#  'gbdt_leaf_indices_491',
#  'gbdt_leaf_indices_492',
#  'gbdt_leaf_indices_493',
#  'gbdt_leaf_indices_494',
#  'gbdt_leaf_indices_495',
#  'gbdt_leaf_indices_496',
#  'gbdt_leaf_indices_497',
#  'gbdt_leaf_indices_498',
#  'gbdt_leaf_indices_499',
#  'gbdt_leaf_indices_500',
#  'gbdt_leaf_indices_501',
#  'gbdt_leaf_indices_502',
#  'gbdt_leaf_indices_503',
#  'gbdt_leaf_indices_504',
#  'gbdt_leaf_indices_505',
#  'gbdt_leaf_indices_506',
#  'gbdt_leaf_indices_507',
#  'gbdt_leaf_indices_508',
#  'gbdt_leaf_indices_509',
#  'gbdt_leaf_indices_510',
#  'gbdt_leaf_indices_511',
#  'gbdt_leaf_indices_512',
#  'gbdt_leaf_indices_513',
#  'gbdt_leaf_indices_514',
#  'gbdt_leaf_indices_515',
#  'gbdt_leaf_indices_516',
#  'gbdt_leaf_indices_517',
#  'gbdt_leaf_indices_518',
#  'gbdt_leaf_indices_519',
#  'gbdt_leaf_indices_520',
#  'gbdt_leaf_indices_521',
#  'gbdt_leaf_indices_522',
#  'gbdt_leaf_indices_523',
#  'gbdt_leaf_indices_524',
#  'gbdt_leaf_indices_525',
#  'gbdt_leaf_indices_526',
#  'gbdt_leaf_indices_527',
#  'gbdt_leaf_indices_528',
#  'gbdt_leaf_indices_529',
#  'gbdt_leaf_indices_530',
#  'gbdt_leaf_indices_531',
#  'gbdt_leaf_indices_532',
#  'gbdt_leaf_indices_533',
#  'gbdt_leaf_indices_534',
#  'gbdt_leaf_indices_535',
#  'gbdt_leaf_indices_536',
#  'gbdt_leaf_indices_537',
#  'gbdt_leaf_indices_538',
#  'gbdt_leaf_indices_539',
#  'gbdt_leaf_indices_540',
#  'gbdt_leaf_indices_541',
#  'gbdt_leaf_indices_542',
#  'gbdt_leaf_indices_543',
#  'gbdt_leaf_indices_544',
#  'gbdt_leaf_indices_545',
#  'gbdt_leaf_indices_546',
#  'gbdt_leaf_indices_547',
#  'gbdt_leaf_indices_548',
#  'gbdt_leaf_indices_549',
#  'gbdt_leaf_indices_550',
#  'gbdt_leaf_indices_551',
#  'gbdt_leaf_indices_552',
#  'gbdt_leaf_indices_553',
#  'gbdt_leaf_indices_554',
#  'gbdt_leaf_indices_555',
#  'gbdt_leaf_indices_556',
#  'gbdt_leaf_indices_557',
#  'gbdt_leaf_indices_558',
#  'gbdt_leaf_indices_559',
#  'gbdt_leaf_indices_560',
#  'gbdt_leaf_indices_561',
#  'gbdt_leaf_indices_562',
#  'gbdt_leaf_indices_563',
#  'gbdt_leaf_indices_564',
#  'gbdt_leaf_indices_565',
#  'gbdt_leaf_indices_566',
#  'gbdt_leaf_indices_567',
#  'gbdt_leaf_indices_568',
#  'gbdt_leaf_indices_569',
#  'gbdt_leaf_indices_570',
#  'gbdt_leaf_indices_571',
#  'gbdt_leaf_indices_572',
#  'gbdt_leaf_indices_573',
#  'gbdt_leaf_indices_574',
#  'gbdt_leaf_indices_575',
#  'gbdt_leaf_indices_576',
#  'gbdt_leaf_indices_577',
#  'gbdt_leaf_indices_578',
#  'gbdt_leaf_indices_579',
#  'gbdt_leaf_indices_580',
#  'gbdt_leaf_indices_581',
#  'gbdt_leaf_indices_582',
#  'gbdt_leaf_indices_583',
#  'gbdt_leaf_indices_584',
#  'gbdt_leaf_indices_585',
#  'gbdt_leaf_indices_586',
#  'gbdt_leaf_indices_587',
#  'gbdt_leaf_indices_588',
#  'gbdt_leaf_indices_589',
#  'gbdt_leaf_indices_590',
#  'gbdt_leaf_indices_591',
#  'gbdt_leaf_indices_592',
#  'gbdt_leaf_indices_593',
#  'gbdt_leaf_indices_594',
#  'gbdt_leaf_indices_595',
#  'gbdt_leaf_indices_596',
#  'gbdt_leaf_indices_597',
#  'gbdt_leaf_indices_598',
#  'gbdt_leaf_indices_599',
#  'gbdt_leaf_indices_600',
#  'gbdt_leaf_indices_601',
#  'gbdt_leaf_indices_602',
#  'gbdt_leaf_indices_603',
#  'gbdt_leaf_indices_604',
#  'gbdt_leaf_indices_605',
#  'gbdt_leaf_indices_606',
#  'gbdt_leaf_indices_607',
#  'gbdt_leaf_indices_608',
#  'gbdt_leaf_indices_609',
#  'gbdt_leaf_indices_610',
#  'gbdt_leaf_indices_611',
#  'gbdt_leaf_indices_612',
#  'gbdt_leaf_indices_613',
#  'gbdt_leaf_indices_614',
#  'gbdt_leaf_indices_615',
#  'gbdt_leaf_indices_616',
#  'gbdt_leaf_indices_617',
#  'gbdt_leaf_indices_618',
#  'gbdt_leaf_indices_619',
#  'gbdt_leaf_indices_620',
#  'gbdt_leaf_indices_621',
#  'gbdt_leaf_indices_622',
#  'gbdt_leaf_indices_623',
#  'gbdt_leaf_indices_624',
#  'gbdt_leaf_indices_625',
#  'gbdt_leaf_indices_626',
#  'gbdt_leaf_indices_627',
#  'gbdt_leaf_indices_628',
#  'gbdt_leaf_indices_629',
#  'gbdt_leaf_indices_630',
#  'gbdt_leaf_indices_631',
#  'gbdt_leaf_indices_632',
#  'gbdt_leaf_indices_633',
#  'gbdt_leaf_indices_634',
#  'gbdt_leaf_indices_635',
#  'gbdt_leaf_indices_636',
#  'gbdt_leaf_indices_637',
#  'gbdt_leaf_indices_638',
#  'gbdt_leaf_indices_639',
#  'gbdt_leaf_indices_640',
#  'gbdt_leaf_indices_641',
#  'gbdt_leaf_indices_642',
#  'gbdt_leaf_indices_643',
#  'gbdt_leaf_indices_644',
#  'gbdt_leaf_indices_645',
#  'gbdt_leaf_indices_646',
#  'gbdt_leaf_indices_647',
#  'gbdt_leaf_indices_648',
#  'gbdt_leaf_indices_649',
#  'gbdt_leaf_indices_650',
#  'gbdt_leaf_indices_651',
#  'gbdt_leaf_indices_652',
#  'gbdt_leaf_indices_653',
#  'gbdt_leaf_indices_654',
#  'gbdt_leaf_indices_655',
#  'gbdt_leaf_indices_656',
#  'gbdt_leaf_indices_657',
#  'gbdt_leaf_indices_658',
#  'gbdt_leaf_indices_659',
#  'gbdt_leaf_indices_660',
#  'gbdt_leaf_indices_661',
#  'gbdt_leaf_indices_662',
#  'gbdt_leaf_indices_663',
#  'gbdt_leaf_indices_664',
#  'gbdt_leaf_indices_665',
#  'gbdt_leaf_indices_666',
#  'gbdt_leaf_indices_667',
#  'gbdt_leaf_indices_668',
#  'gbdt_leaf_indices_669',
#  'gbdt_leaf_indices_670',
#  'gbdt_leaf_indices_671',
#  'gbdt_leaf_indices_672',
#  'gbdt_leaf_indices_673',
#  'gbdt_leaf_indices_674',
#  'gbdt_leaf_indices_675',
#  'gbdt_leaf_indices_676',
#  'gbdt_leaf_indices_677',
#  'gbdt_leaf_indices_678',
#  'gbdt_leaf_indices_679',
#  'gbdt_leaf_indices_680',
#  'gbdt_leaf_indices_681',
#  'gbdt_leaf_indices_682',
#  'gbdt_leaf_indices_683',
#  'gbdt_leaf_indices_684',
#  'gbdt_leaf_indices_685',
#  'gbdt_leaf_indices_686',
#  'gbdt_leaf_indices_687',
#  'gbdt_leaf_indices_688',
#  'gbdt_leaf_indices_689',
#  'gbdt_leaf_indices_690',
#  'gbdt_leaf_indices_691',
#  'gbdt_leaf_indices_692',
#  'gbdt_leaf_indices_693',
#  'gbdt_leaf_indices_694',
#  'gbdt_leaf_indices_695',
#  'gbdt_leaf_indices_696',
#  'gbdt_leaf_indices_697',
#  'gbdt_leaf_indices_698',
#  'gbdt_leaf_indices_699',
#  'gbdt_leaf_indices_700',
#  'gbdt_leaf_indices_701',
#  'gbdt_leaf_indices_702',
#  'gbdt_leaf_indices_703',
#  'gbdt_leaf_indices_704',
#  'gbdt_leaf_indices_705',
#  'gbdt_leaf_indices_706',
#  'gbdt_leaf_indices_707',
#  'gbdt_leaf_indices_708',
#  'gbdt_leaf_indices_709',
#  'gbdt_leaf_indices_710',
#  'gbdt_leaf_indices_711',
#  'gbdt_leaf_indices_712',
#  'gbdt_leaf_indices_713',
#  'gbdt_leaf_indices_714',
#  'gbdt_leaf_indices_715',
#  'gbdt_leaf_indices_716',
#  'gbdt_leaf_indices_717',
#  'gbdt_leaf_indices_718',
#  'gbdt_leaf_indices_719',
#  'gbdt_leaf_indices_720',
#  'gbdt_leaf_indices_721',
#  'gbdt_leaf_indices_722',
#  'gbdt_leaf_indices_723',
#  'gbdt_leaf_indices_724',
#  'gbdt_leaf_indices_725',
#  'gbdt_leaf_indices_726',
#  'gbdt_leaf_indices_727',
#  'gbdt_leaf_indices_728',
#  'gbdt_leaf_indices_729',
#  'gbdt_leaf_indices_730',
#  'gbdt_leaf_indices_731',
#  'gbdt_leaf_indices_732',
#  'gbdt_leaf_indices_733',
#  'gbdt_leaf_indices_734',
#  'gbdt_leaf_indices_735',
#  'gbdt_leaf_indices_736',
#  'gbdt_leaf_indices_737',
#  'gbdt_leaf_indices_738',
#  'gbdt_leaf_indices_739',
#  'gbdt_leaf_indices_740',
#  'gbdt_leaf_indices_741',
#  'gbdt_leaf_indices_742',
#  'gbdt_leaf_indices_743',
#  'gbdt_leaf_indices_744',
#  'gbdt_leaf_indices_745',
#  'gbdt_leaf_indices_746',
#  'gbdt_leaf_indices_747',
#  'gbdt_leaf_indices_748',
#  'gbdt_leaf_indices_749',
#  'gbdt_leaf_indices_750',
#  'gbdt_leaf_indices_751',
#  'gbdt_leaf_indices_752',
#  'gbdt_leaf_indices_753',
#  'gbdt_leaf_indices_754',
#  'gbdt_leaf_indices_755',
#  'gbdt_leaf_indices_756',
#  'gbdt_leaf_indices_757',
#  'gbdt_leaf_indices_758',
#  'gbdt_leaf_indices_759',
#  'gbdt_leaf_indices_760',
#  'gbdt_leaf_indices_761',
#  'gbdt_leaf_indices_762',
#  'gbdt_leaf_indices_763',
#  'gbdt_leaf_indices_764',
#  'gbdt_leaf_indices_765',
#  'gbdt_leaf_indices_766',
#  'gbdt_leaf_indices_767',
#  'gbdt_leaf_indices_768',
#  'gbdt_leaf_indices_769',
#  'gbdt_leaf_indices_770',
#  'gbdt_leaf_indices_771',
#  'gbdt_leaf_indices_772',
#  'gbdt_leaf_indices_773',
#  'gbdt_leaf_indices_774',
#  'gbdt_leaf_indices_775',
#  'gbdt_leaf_indices_776',
#  'gbdt_leaf_indices_777',
#  'gbdt_leaf_indices_778',
#  'gbdt_leaf_indices_779',
#  'gbdt_leaf_indices_780',
#  'gbdt_leaf_indices_781',
#  'gbdt_leaf_indices_782',
#  'gbdt_leaf_indices_783',
#  'gbdt_leaf_indices_784',
#  'gbdt_leaf_indices_785',
#  'gbdt_leaf_indices_786',
#  'gbdt_leaf_indices_787',
#  'gbdt_leaf_indices_788',
#  'gbdt_leaf_indices_789',
#  'gbdt_leaf_indices_790',
#  'gbdt_leaf_indices_791',
#  'gbdt_leaf_indices_792',
#  'gbdt_leaf_indices_793',
#  'gbdt_leaf_indices_794',
#  'gbdt_leaf_indices_795',
#  'gbdt_leaf_indices_796',
#  'gbdt_leaf_indices_797',
#  'gbdt_leaf_indices_798',
#  'gbdt_leaf_indices_799',
#  'gbdt_leaf_indices_800',
#  'gbdt_leaf_indices_801',
#  'gbdt_leaf_indices_802',
#  'gbdt_leaf_indices_803',
#  'gbdt_leaf_indices_804',
#  'gbdt_leaf_indices_805',
#  'gbdt_leaf_indices_806',
#  'gbdt_leaf_indices_807',
#  'gbdt_leaf_indices_808',
#  'gbdt_leaf_indices_809',
#  'gbdt_leaf_indices_810',
#  'gbdt_leaf_indices_811',
#  'gbdt_leaf_indices_812',
#  'gbdt_leaf_indices_813',
#  'gbdt_leaf_indices_814',
#  'gbdt_leaf_indices_815',
#  'gbdt_leaf_indices_816',
#  'gbdt_leaf_indices_817']

# %%
combineDf = pd.concat([combineDf, pd.DataFrame(data=gbdt_feats_vals, index=range(0, gbdt_feats_vals.shape[0]),columns=gbdt_columns)], axis=1)

# %%
"""
因为是采用GBDT+LR方案：将GBDT的输出节点index做出LR的输入，必须将LR的节点index进行one-hot编码；
如果是采用GBDT+FM方案：则无需将GBDT的输出index进行编码，而是需要按照FM的形式进行组织！
"""

# onehotencoder(gbdt_feats)
origin_columns = combineDf.columns
for col in gbdt_columns:
    combineDf = pd.concat([combineDf, pd.get_dummies(combineDf[col], prefix=col)],axis=1)
gbdt_onehot_feats = [col for col in combineDf.columns if col not in origin_columns]

# %%
# 恢复train, test
train = combineDf[:train_sz]
test = combineDf[train_sz:]
del combineDf; gc.collect();

# %%
"""
这里是将在原特征（缩放后的连续特征 + one-hot编码后的（bin特征以及类别特征））与
利用GBDT生成的特征进行联立，其中# lr_feats = lr_feats = con_feats + onehot_feats
"""


lr_gbdt_feats = lr_feats + gbdt_onehot_feats

# %%
lr_gbdt_model = LogisticRegression(penalty='l2', C=1)
lr_gbdt_model.fit(train[lr_gbdt_feats], train[label])
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print("Train................")
do_model_metric(y_true=train[label], y_pred=lr_gbdt_model.predict(train[lr_gbdt_feats]), y_pred_prob=lr_gbdt_model.predict_proba(train[lr_gbdt_feats]))

print("Test..................")
do_model_metric(y_true=test[label], y_pred=lr_gbdt_model.predict(test[lr_gbdt_feats]), y_pred_prob=lr_gbdt_model.predict_proba(test[lr_gbdt_feats]))
# Out:
# Train................
# Predict 1 percent: 0.5304445155100735
# Label 1 percent: 0.5215542053086025
# AUC: 0.739
# Accuracy: 0.6719539494723377
# Test..................
# Predict 1 percent: 0.5292594013814275
# Label 1 percent: 0.5215542053086025
# AUC: 0.589
# Accuracy: 0.5635072908672295
